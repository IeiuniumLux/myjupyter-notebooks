# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import sys, os, math, random, functools

import numpy as np

import matplotlib
import matplotlib.pyplot as pp
import matplotlib.animation as anim

# %matplotlib inline

from IPython.display import display, HTML

# %% [markdown]
# ### Code from previous videos

# %%
from turtle import Turtle, Terrarium

# %%
def fb(turtle,distance):
    turtle.forward(distance)
    turtle.back(distance)

Turtle.fb = fb

# %%
def F(dist):
    return functools.partial(Turtle.forward,distance=dist)

def L(ang):
    return functools.partial(Turtle.left,angle=ang)

# %%
def iterated(f,n):
    def iterf(arg):
        ret = arg
        for i in range(n):
            ret = f(ret)
        return ret
    
    return iterf

# %% [markdown]
# ## A fractal tree: solution

# %%
def FB(dist):
    return functools.partial(Turtle.fb,distance=dist)

# %%
def funcbranch(steps):
    newsteps = []
    
    for step in steps:
        if step.func == Turtle.fb:
            dist = step.keywords['distance']
            newsteps += [F(dist),L(45),FB(dist/2),L(-90),FB(dist/2),L(45),F(-dist)]
        else:
            newsteps += [step]
    
    return newsteps

# %%
with Terrarium(animate=True) as t:
    t1 = Turtle(t)
    t1.left(90)

    for step in iterated(funcbranch,6)([FB(100)]):
        step(t1)
# Out:
# [functools.partial(<function Turtle.forward at 0x119d35950>, distance=100), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-100)]
# [functools.partial(<function Turtle.forward at 0x119d35950>, distance=100), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-100)]
# [functools.partial(<function Turtle.forward at 0x119d35950>, distance=100), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-100)]
# [functools.partial(<function Turtle.forward at 0x119d35950>, distance=100), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12 ...
# [functools.partial(<function Turtle.forward at 0x119d35950>, distance=100), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, dis ...
# [functools.partial(<function Turtle.forward at 0x119d35950>, distance=100), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=50.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=25.0), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function fb at 0x119d3f268>, distance=1.5625), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=-12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=-90), functools.partial(<function Turtle.forward at 0x119d35950>, distance=12.5), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=6.25), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<function Turtle.forward at 0x119d35950>, distance=3.125), functools.partial(<function Turtle.left at 0x119d35a60>, angle=45), functools.partial(<funct ...
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
